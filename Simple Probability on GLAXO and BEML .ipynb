# %%
import pandas as pd
import numpy as np

beml_df=pd.read_csv(r"C:\Users\sidra\Downloads\BEML.csv")
glaxo_df=pd.read_csv(r"C:\Users\sidra\Downloads\GLAXO.csv")

# %%
print(beml_df)
print(glaxo_df)
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     04-01-2010  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     05-01-2010  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     06-01-2010  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     07-01-2010  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     08-01-2010  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  26-12-2016   965.00   965.05   935.00   950.10   950.25
# 1735  27-12-2016   960.70   989.00   952.35   974.00   975.70
# 1736  28-12-2016   980.75   985.00   970.15   977.00   974.40
# 1737  29-12-2016   977.10   997.95   974.55   985.15   986.05
# 1738  30-12-2016   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                   101651          1157.18
# 1                    59504           676.47
# 2                   128908          1482.84
# 3                   117871          1352.98
# 4                   170063          1971.42
# ...                    ...              ...
# 1734                398696          3783.63
# 1735                808561          7885.14
# 1736                367041          3592.49
# 1737                555233          5489.14
# 1738                460675          4606.48
#
# [1739 rows x 8 columns]
#             Date     Open     High      Low    Last    Close  \
# 0     2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1     2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2     2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3     2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4     2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
# ...          ...      ...      ...      ...     ...      ...
# 1734  2016-12-26  2703.00  2740.00  2677.00  2715.0  2723.50
# 1735  2016-12-27  2722.95  2725.00  2683.00  2692.0  2701.75
# 1736  2016-12-28  2701.75  2718.00  2690.00  2698.0  2702.15
# 1737  2016-12-29  2702.05  2739.00  2691.95  2710.0  2727.90
# 1738  2016-12-30  2730.00  2740.45  2705.00  2730.0  2729.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                   9365.0           151.74
# 1                  38148.0           622.58
# 2                  36519.0           595.09
# 3                  12809.0           211.00
# 4                  28035.0           459.11
# ...                    ...              ...
# 1734                3953.0           107.15
# 1735               10600.0           286.10
# 1736                6050.0           163.44
# 1737                7649.0           207.87
# 1738                6513.0           177.65
#
# [1739 rows x 8 columns]

# %%
import seaborn as sn

# %%
glaxo_df['gain']=glaxo_df.Close.pct_change(periods=1)
beml_df['gain']=beml_df.Close.pct_change(periods=1)

# %%
glaxo_df=glaxo_df.dropna()
beml_df=beml_df.dropna()

# %%
import matplotlib.pyplot as plt

sn.distplot(glaxo_df.gain, label = 'Glaxo');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\sidra\AppData\Local\Temp\ipykernel_10408\558871297.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(glaxo_df.gain, label = 'Glaxo');

# %%
sn.distplot(beml_df.gain, label = 'BEML');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\sidra\AppData\Local\Temp\ipykernel_10408\2294063147.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(beml_df.gain, label = 'BEML');

# %%
sn.distplot(glaxo_df.gain, label = 'Glaxo');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
sn.distplot(beml_df.gain, label = 'BEML');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\sidra\AppData\Local\Temp\ipykernel_10408\2853241747.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(glaxo_df.gain, label = 'Glaxo');
# C:\Users\sidra\AppData\Local\Temp\ipykernel_10408\2853241747.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(beml_df.gain, label = 'BEML');

# %%
print('Mean:', round(glaxo_df.gain.mean(), 4))
print('Standard Deviation: ', round(glaxo_df.gain.std(), 4))
# Out:
# Mean: 0.0004
# Standard Deviation:  0.0134

# %%
print('Mean:', round(beml_df.gain.mean(), 4))
print('Standard Deviation: ',round(beml_df.gain.std(), 4))
# Out:
# Mean: 0.0003
# Standard Deviation:  0.0264

# %%
from scipy import stats

# %% [markdown]
# Probability of making
# 2% loss or higher in Glaxo: 0.063 or 6.3%

# %%
stats.norm.cdf(-0.02,
loc=glaxo_df.gain.mean(),
scale=glaxo_df.gain.std())
# Out:
# 0.06352488667177397

# %% [markdown]
# Probability of making
# 2% loss or higher in BEML: 0.2215 or 22.3%

# %%
stats.norm.cdf(-0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22155987503755287

# %% [markdown]
# Probability of making
#  2% gain or higher in Glaxo: 0.0710 or 7.1%

# %%
1 - stats.norm.cdf(0.02,
loc=glaxo_df.gain.mean(),
scale=glaxo_df.gain.std())
# Out:
# 0.07104511457618568

# %% [markdown]
# Probability of making
# 2% gain or higher in BEML: 0.2276 or 22.76%

# %%
1 - stats.norm.cdf(0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22769829484075355
